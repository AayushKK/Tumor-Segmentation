# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import json
from zipfile import ZipFile
import shutil
from glob import glob
from tqdm import tqdm

#Data
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("dark_background")

#Image
import cv2 as cv
import cv2
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

#keras
import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import warnings
warnings.filterwarnings("ignore")

# %%
IMG_SIZE = (256,256)

# %%
train_files = []
mask_files = glob("/content/drive/MyDrive/kaggle_3m/*/*_mask*")

for f in tqdm(mask_files):
    train_files.append(f.replace('_mask', ''))
# Out:
# 100%|██████████| 3929/3929 [00:00<00:00, 1171744.91it/s]

# %%
df = pd.DataFrame({"image_path": train_files, "mask_path":mask_files})

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.15, shuffle = True)
df_train, df_val = train_test_split(df_train, test_size=0.15, shuffle = True)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (2838, 2)
# (501, 2)
# (590, 2)

# %%
def adjust(img,mask):
    #normalization
    img = img / 255.

    #mask
    mask = mask / 255.
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0

    return (img, mask)

# %%
train_gen_aug = dict(rotation_range=0.2,
                        width_shift_range=0.05,
                        height_shift_range=0.05,
                        shear_range=0.05,
                        zoom_range=0.05,
                        horizontal_flip=True,
                        fill_mode='nearest')

# %%
def train_generator(dataframe, batch_size, aug_dict,
                    image_color_mode = "rgb",
                    mask_color_mode = "grayscale",
                    image_save_prefix = "image",
                    mask_save_prefix = "mask",
                    save_to_dir = None,
                    target_size = (256,256),
                    seed = 1):
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)

  #image
    image_generator = image_datagen.flow_from_dataframe(
          dataframe,
          x_col = "image_path",
          target_size = target_size,
          batch_size = batch_size,
          class_mode = None,
          color_mode = image_color_mode,
          save_to_dir = save_to_dir,
          save_prefix = image_save_prefix,
          seed = seed )

      #mask
    mask_generator = mask_datagen.flow_from_dataframe(
          dataframe,
          x_col = "mask_path",
          target_size = target_size,
          batch_size = batch_size,
          class_mode = None,
          color_mode = mask_color_mode,
          save_to_dir = save_to_dir,
          save_prefix = mask_save_prefix,
          seed = seed)

  #combining the generators to make a whole generator
    train_gen = zip(image_generator, mask_generator)

  #data adjustment
    for (img, mask) in train_gen:
        img, mask = adjust(img, mask)
        yield (img,mask)

# %%
def conv_block(tensor, nfilters, padding='same', initializer="he_normal"):
    #residual connection
    res = Conv2D(filters=nfilters, kernel_size=(1,1), padding = padding, kernel_initializer=initializer)(tensor)
    res = BatchNormalization()(res)

    #path-1-1(low)
    low = Conv2D(filters=nfilters, kernel_size=(3,3), padding=padding, kernel_initializer=initializer)(tensor)
    low = BatchNormalization()(low)

    #path-1-2(high)
    high = Conv2D(filters=nfilters, kernel_size=(3,3), padding=padding, kernel_initializer=initializer)(tensor)
    high = BatchNormalization()(high)
    high = Activation("relu")(high)
    high = Conv2D(filters=nfilters, kernel_size=(3,3), padding=padding, kernel_initializer=initializer)(high)
    high = BatchNormalization()(high)
    high = Activation("relu")(high)
    high = Conv2D(filters=nfilters, kernel_size=(3,3), padding=padding, kernel_initializer=initializer)(high)
    high = BatchNormalization()(high)

    #concatenate
    out = concatenate([low, high], axis = 3)
    out = Activation("relu")(out)

    #path-2-1(low)
    low = Conv2D(filters=nfilters, kernel_size=(3,3), padding=padding, kernel_initializer=initializer)(out)
    low = BatchNormalization()(low)

    #path-2-2(high)
    high = Conv2D(filters=nfilters, kernel_size=(3,3), padding=padding, kernel_initializer=initializer)(out)
    high = BatchNormalization()(high)
    high = Activation("relu")(high)
    high = Conv2D(filters=nfilters, kernel_size=(3,3), padding=padding, kernel_initializer=initializer)(high)
    high = BatchNormalization()(high)

    #concatenate
    out = concatenate([low, high, res], axis = 3)
    out = Activation("relu")(out)

    return out

# %%
def pooling(tensor):
    pool_1 = MaxPooling2D(pool_size=(2, 2))(tensor)
    pool_2 = AveragePooling2D(pool_size=(2, 2))(tensor)
    out = concatenate([pool_1, pool_2], axis = 3)
    return out

# %%
def unet(input_size = (256,256,3)):
    #Input Layer
    inputs = Input(input_size)

    #Encoder network
    conv1 = conv_block(inputs,16)
    pool1 = pooling(conv1)

    conv2 = conv_block(pool1,32)
    pool2 = pooling(conv2)

    conv3 = conv_block(pool2,64)
    pool3 = pooling(conv3)

    conv4 = conv_block(pool3,128)
    pool4 = pooling(conv4)

    conv5 = conv_block(pool4,256)

    #decoder network
    up6 = Conv2DTranspose(128, (2,2), strides = (2,2), padding = "same")(conv5)
    up6 = concatenate([up6, conv4], axis = 3)
    conv6 = conv_block(up6,128)

    up7 = Conv2DTranspose(64, (2,2), strides = (2,2), padding = "same")(conv6)
    up7 = concatenate([up7, conv3], axis = 3)
    conv7 = conv_block(up7,64)

    up8 = Conv2DTranspose(32, (2,2), strides = (2,2), padding = "same")(conv7)
    up8 = concatenate([up8, conv2], axis = 3)
    conv8 = conv_block(up8,32)

    up9 = Conv2DTranspose(16, (2,2), strides = (2,2), padding = "same")(conv8)
    up9 = concatenate([up9, conv1], axis = 3)
    conv9 = conv_block(up9,16)

    #output layer
    conv10 = Conv2D(1, (1,1), activation= "sigmoid")(conv9)

    model = Model(inputs = [inputs], outputs = [conv10])

    return model

# %%
BATCH_SIZE = 16

# %%
train_gen = train_generator(df_train, batch_size= BATCH_SIZE,
                            aug_dict = train_gen_aug,
                            target_size = IMG_SIZE)
test_gen = train_generator(df_val, batch_size = BATCH_SIZE,
                           aug_dict = dict(),
                           target_size = IMG_SIZE)
model = unet((IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
EPOCHS = 35
BATCH_SIZE = 16
learning_rate = 0.05

# %%
from keras import backend as K
import numpy as np
import tensorflow as tf
from scipy.ndimage import distance_transform_edt as distance


def calc_dist_map(seg):
    res = np.zeros_like(seg)
    posmask = seg.astype(np.bool)

    if posmask.any():
        negmask = ~posmask
        res = distance(negmask) * negmask - (distance(posmask) - 1) * posmask

    return res


def calc_dist_map_batch(y_true):
    y_true_numpy = y_true.numpy()
    return np.array([calc_dist_map(y)
                     for y in y_true_numpy]).astype(np.float32)


def surface_loss(y_true, y_pred):
    y_true_dist_map = tf.py_function(func=calc_dist_map_batch,
                                     inp=[y_true],
                                     Tout=tf.float32)
    multipled = y_pred * y_true_dist_map
    return K.mean(multipled)

# %%
from keras.losses import binary_crossentropy

beta = 0.25
alpha = 0.25
gamma = 2
epsilon = 1e-5
smooth = 1


class Semantic_loss_functions(object):
    def __init__(self):
        print ("semantic loss functions initialized")

    def dice_coef(self, y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + K.epsilon()) / (
                    K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

    def sensitivity(self, y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        return true_positives / (possible_positives + K.epsilon())

    def specificity(self, y_true, y_pred):
        true_negatives = K.sum(
            K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
        possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
        return true_negatives / (possible_negatives + K.epsilon())

    def convert_to_logits(self, y_pred):
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(),
                                  1 - tf.keras.backend.epsilon())
        return tf.math.log(y_pred / (1 - y_pred))

    def weighted_cross_entropyloss(self, y_true, y_pred):
        y_pred = self.convert_to_logits(y_pred)
        pos_weight = beta / (1 - beta)
        loss = tf.nn.weighted_cross_entropy_with_logits(y_true,y_pred,pos_weight)
        return tf.reduce_mean(loss)

    def focal_loss_with_logits(self, logits, targets, alpha, gamma, y_pred):
        weight_a = alpha * (1 - y_pred) ** gamma * targets
        weight_b = (1 - alpha) * y_pred ** gamma * (1 - targets)

        return (tf.math.log1p(tf.exp(-tf.abs(logits))) + tf.nn.relu(
            -logits)) * (weight_a + weight_b) + logits * weight_b

    def focal_loss(self, y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(),
                                  1 - tf.keras.backend.epsilon())
        logits = tf.math.log(y_pred / (1 - y_pred))

        loss = self.focal_loss_with_logits(logits=logits, targets=y_true,
                                      alpha=alpha, gamma=gamma, y_pred=y_pred)

        return tf.reduce_mean(loss)

    def depth_softmax(self, matrix):
        sigmoid = lambda x: 1 / (1 + K.exp(-x))
        sigmoided_matrix = sigmoid(matrix)
        softmax_matrix = sigmoided_matrix / K.sum(sigmoided_matrix, axis=0)
        return softmax_matrix

    def dice_coefficient(self, y_true, y_pred):
        smooth = 1.
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        score = (2. * intersection + smooth) / (
                    K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
        return score

    def dice_loss(self, y_true, y_pred):
        loss = 1 - self.dice_coefficient(y_true, y_pred)
        return loss

    def bce_dice_loss(self, y_true, y_pred):
        loss = binary_crossentropy(y_true, y_pred) + \
               self.dice_loss(y_true, y_pred)
        return loss / 2.0

    def confusion(self, y_true, y_pred):
        smooth = 1
        y_pred_pos = K.clip(y_pred, 0, 1)
        y_pred_neg = 1 - y_pred_pos
        y_pos = K.clip(y_true, 0, 1)
        y_neg = 1 - y_pos
        tp = K.sum(y_pos * y_pred_pos)
        fp = K.sum(y_neg * y_pred_pos)
        fn = K.sum(y_pos * y_pred_neg)
        prec = (tp + smooth) / (tp + fp + smooth)
        recall = (tp + smooth) / (tp + fn + smooth)
        return prec, recall

    def true_positive(self, y_true, y_pred):
        smooth = 1
        y_pred_pos = K.round(K.clip(y_pred, 0, 1))
        y_pos = K.round(K.clip(y_true, 0, 1))
        tp = (K.sum(y_pos * y_pred_pos) + smooth) / (K.sum(y_pos) + smooth)
        return tp

    def true_negative(self, y_true, y_pred):
        smooth = 1
        y_pred_pos = K.round(K.clip(y_pred, 0, 1))
        y_pred_neg = 1 - y_pred_pos
        y_pos = K.round(K.clip(y_true, 0, 1))
        y_neg = 1 - y_pos
        tn = (K.sum(y_neg * y_pred_neg) + smooth) / (K.sum(y_neg) + smooth)
        return tn

    def tversky_index(self, y_true, y_pred):
        y_true_pos = K.flatten(y_true)
        y_pred_pos = K.flatten(y_pred)
        true_pos = K.sum(y_true_pos * y_pred_pos)
        false_neg = K.sum(y_true_pos * (1 - y_pred_pos))
        false_pos = K.sum((1 - y_true_pos) * y_pred_pos)
        alpha = 0.7
        return (true_pos + smooth) / (true_pos + alpha * false_neg + (
                    1 - alpha) * false_pos + smooth)

    def tversky_loss(self, y_true, y_pred):
        return 1 - self.tversky_index(y_true, y_pred)

    def focal_tversky(self, y_true, y_pred):
        pt_1 = self.tversky_index(y_true, y_pred)
        gamma = 0.75
        return K.pow((1 - pt_1), gamma)

    def log_cosh_dice_loss(self, y_true, y_pred):
        x = self.dice_loss(y_true, y_pred)
        return tf.math.log((tf.exp(x) + tf.exp(-x)) / 2.0)

    def loss(self, y_true, y_pred):
        return 0.5*s.focal_tversky(y_true, y_pred) + 0.2*self.weighted_cross_entropyloss(y_true, y_pred) + 0.3*surface_loss(y_true, y_pred)

s = Semantic_loss_functions()
# Out:
# semantic loss functions initialized

# %%
decay_rate = learning_rate / EPOCHS
opt = Adam(learning_rate=learning_rate, epsilon= 0.1, decay=decay_rate, amsgrad=False)

# %%
model.compile(optimizer = opt, loss = s.loss, metrics = ["binary_accuracy", s.tversky_index, s.dice_coefficient, s.sensitivity, s.specificity ])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 16  448         ['input_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation (Activation)        (None, 256, 256, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 16  2320        ['activation[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 16  64         ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  448         ['input_1[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 16  2320        ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  batch_normalization_4 (BatchNo  (None, 256, 256, 16  64         ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  concatenate (Concatenate)      (None, 256, 256, 32  0           ['batch_normalization_1[0][0]',
#                                 )                                 'batch_normalization_4[0][0]']
#
#  activation_2 (Activation)      (None, 256, 256, 32  0           ['concatenate[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 16  4624        ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 16  64         ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 16  4624        ['activation_2[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 16  2320        ['activation_3[0][0]']
#                                 )
#
#  conv2d (Conv2D)                (None, 256, 256, 16  64          ['input_1[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 256, 256, 16  64         ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 16  64         ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  concatenate_1 (Concatenate)    (None, 256, 256, 48  0           ['batch_normalization_5[0][0]',
#                                 )                                 'batch_normalization_7[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  activation_4 (Activation)      (None, 256, 256, 48  0           ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 48  0           ['activation_4[0][0]']
#                                 )
#
#  average_pooling2d (AveragePool  (None, 128, 128, 48  0          ['activation_4[0][0]']
#  ing2D)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 96  0           ['max_pooling2d[0][0]',
#                                 )                                 'average_pooling2d[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 32  27680       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 128, 128, 32  128        ['conv2d_10[0][0]']
#  ormalization)                  )
#
#  activation_5 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 32  9248        ['activation_5[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 128, 128, 32  128        ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  activation_6 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 32  27680       ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 32  9248        ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 128, 128, 32  128        ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 32  128        ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 64  0           ['batch_normalization_9[0][0]',
#                                 )                                 'batch_normalization_12[0][0]']
#
#  activation_7 (Activation)      (None, 128, 128, 64  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 32  18464       ['activation_7[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 32  128        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  activation_8 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 32  18464       ['activation_7[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 32  9248        ['activation_8[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 32  3104        ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 32  128        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 32  128        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  batch_normalization_8 (BatchNo  (None, 128, 128, 32  128        ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  concatenate_4 (Concatenate)    (None, 128, 128, 96  0           ['batch_normalization_13[0][0]',
#                                 )                                 'batch_normalization_15[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_9 (Activation)      (None, 128, 128, 96  0           ['concatenate_4[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 96)  0           ['activation_9[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 64, 64, 96)  0           ['activation_9[0][0]']
#  oling2D)
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 192)  0           ['max_pooling2d_1[0][0]',
#                                                                   'average_pooling2d_1[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 64)   110656      ['concatenate_5[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 64, 64, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_10[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 64)   110656      ['concatenate_5[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_11[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 64, 64, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 128)  0           ['batch_normalization_17[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_12 (Activation)     (None, 64, 64, 128)  0           ['concatenate_6[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 64)   73792       ['activation_12[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 64)  256         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 64)   73792       ['activation_12[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_13[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 64)   12352       ['concatenate_5[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  concatenate_7 (Concatenate)    (None, 64, 64, 192)  0           ['batch_normalization_21[0][0]',
#                                                                   'batch_normalization_23[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_14 (Activation)     (None, 64, 64, 192)  0           ['concatenate_7[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 192)  0          ['activation_14[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 32, 32, 192)  0          ['activation_14[0][0]']
#  oling2D)
#
#  concatenate_8 (Concatenate)    (None, 32, 32, 384)  0           ['max_pooling2d_2[0][0]',
#                                                                   'average_pooling2d_2[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 128)  442496      ['concatenate_8[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_15[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 128)  512        ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 128)  442496      ['concatenate_8[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_16[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 128)  512        ['conv2d_28[0][0]']
#  ormalization)
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 256)  0           ['batch_normalization_25[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_17 (Activation)     (None, 32, 32, 256)  0           ['concatenate_9[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 128)  295040      ['activation_17[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 128)  512        ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 128)  295040      ['activation_17[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_18[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 128)  49280       ['concatenate_8[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 128)  512        ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 128)  512        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 128)  512        ['conv2d_24[0][0]']
#  ormalization)
#
#  concatenate_10 (Concatenate)   (None, 32, 32, 384)  0           ['batch_normalization_29[0][0]',
#                                                                   'batch_normalization_31[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_19 (Activation)     (None, 32, 32, 384)  0           ['concatenate_10[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 384)  0          ['activation_19[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 16, 16, 384)  0          ['activation_19[0][0]']
#  oling2D)
#
#  concatenate_11 (Concatenate)   (None, 16, 16, 768)  0           ['max_pooling2d_3[0][0]',
#                                                                   'average_pooling2d_3[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 256)  1769728     ['concatenate_11[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_20[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 256)  1769728     ['concatenate_11[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_21[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_36[0][0]']
#  ormalization)
#
#  concatenate_12 (Concatenate)   (None, 16, 16, 512)  0           ['batch_normalization_33[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  activation_22 (Activation)     (None, 16, 16, 512)  0           ['concatenate_12[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 256)  1179904     ['activation_22[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 256)  1179904     ['activation_22[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_23[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 256)  196864      ['concatenate_11[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_39[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  concatenate_13 (Concatenate)   (None, 16, 16, 768)  0           ['batch_normalization_37[0][0]',
#                                                                   'batch_normalization_39[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  activation_24 (Activation)     (None, 16, 16, 768)  0           ['concatenate_13[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 128)  393344     ['activation_24[0][0]']
#  ose)
#
#  concatenate_14 (Concatenate)   (None, 32, 32, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'activation_19[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 128)  589952      ['concatenate_14[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 32, 32, 128)  512        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_25[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 32, 32, 128)  512        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 32, 32, 128)  589952      ['concatenate_14[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_26[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 32, 32, 128)  512        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 32, 32, 128)  512        ['conv2d_44[0][0]']
#  ormalization)
#
#  concatenate_15 (Concatenate)   (None, 32, 32, 256)  0           ['batch_normalization_41[0][0]',
#                                                                   'batch_normalization_44[0][0]']
#
#  activation_27 (Activation)     (None, 32, 32, 256)  0           ['concatenate_15[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 32, 32, 128)  295040      ['activation_27[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 32, 32, 128)  512        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 128)  295040      ['activation_27[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_28[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 128)  65664       ['concatenate_14[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 32, 32, 128)  512        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 32, 32, 128)  512        ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 32, 32, 128)  512        ['conv2d_40[0][0]']
#  ormalization)
#
#  concatenate_16 (Concatenate)   (None, 32, 32, 384)  0           ['batch_normalization_45[0][0]',
#                                                                   'batch_normalization_47[0][0]',
#                                                                   'batch_normalization_40[0][0]']
#
#  activation_29 (Activation)     (None, 32, 32, 384)  0           ['concatenate_16[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 64)  98368       ['activation_29[0][0]']
#  spose)
#
#  concatenate_17 (Concatenate)   (None, 64, 64, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_14[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 64, 64, 64)   147520      ['concatenate_17[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 64, 64, 64)  256         ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_30[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 64, 64, 64)  256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 64, 64, 64)   147520      ['concatenate_17[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_31[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 64, 64, 64)  256         ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 64, 64, 64)  256         ['conv2d_52[0][0]']
#  ormalization)
#
#  concatenate_18 (Concatenate)   (None, 64, 64, 128)  0           ['batch_normalization_49[0][0]',
#                                                                   'batch_normalization_52[0][0]']
#
#  activation_32 (Activation)     (None, 64, 64, 128)  0           ['concatenate_18[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 64, 64, 64)   73792       ['activation_32[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 64, 64, 64)  256         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_54[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 64)   73792       ['activation_32[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_33[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 64, 64, 64)   16448       ['concatenate_17[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 64, 64, 64)  256         ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_55 (BatchN  (None, 64, 64, 64)  256         ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 64, 64, 64)  256         ['conv2d_48[0][0]']
#  ormalization)
#
#  concatenate_19 (Concatenate)   (None, 64, 64, 192)  0           ['batch_normalization_53[0][0]',
#                                                                   'batch_normalization_55[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  activation_34 (Activation)     (None, 64, 64, 192)  0           ['concatenate_19[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 32  24608      ['activation_34[0][0]']
#  spose)                         )
#
#  concatenate_20 (Concatenate)   (None, 128, 128, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'activation_9[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 128, 128, 32  36896       ['concatenate_20[0][0]']
#                                 )
#
#  batch_normalization_58 (BatchN  (None, 128, 128, 32  128        ['conv2d_58[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_58[0][0]']
#                                 )
#
#  conv2d_59 (Conv2D)             (None, 128, 128, 32  9248        ['activation_35[0][0]']
#                                 )
#
#  batch_normalization_59 (BatchN  (None, 128, 128, 32  128        ['conv2d_59[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_59[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 32  36896       ['concatenate_20[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 128, 128, 32  9248        ['activation_36[0][0]']
#                                 )
#
#  batch_normalization_57 (BatchN  (None, 128, 128, 32  128        ['conv2d_57[0][0]']
#  ormalization)                  )
#
#  batch_normalization_60 (BatchN  (None, 128, 128, 32  128        ['conv2d_60[0][0]']
#  ormalization)                  )
#
#  concatenate_21 (Concatenate)   (None, 128, 128, 64  0           ['batch_normalization_57[0][0]',
#                                 )                                 'batch_normalization_60[0][0]']
#
#  activation_37 (Activation)     (None, 128, 128, 64  0           ['concatenate_21[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 128, 128, 32  18464       ['activation_37[0][0]']
#                                 )
#
#  batch_normalization_62 (BatchN  (None, 128, 128, 32  128        ['conv2d_62[0][0]']
#  ormalization)                  )
#
#  activation_38 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_62[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 128, 128, 32  18464       ['activation_37[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 128, 128, 32  9248        ['activation_38[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 32  4128        ['concatenate_20[0][0]']
#                                 )
#
#  batch_normalization_61 (BatchN  (None, 128, 128, 32  128        ['conv2d_61[0][0]']
#  ormalization)                  )
#
#  batch_normalization_63 (BatchN  (None, 128, 128, 32  128        ['conv2d_63[0][0]']
#  ormalization)                  )
#
#  batch_normalization_56 (BatchN  (None, 128, 128, 32  128        ['conv2d_56[0][0]']
#  ormalization)                  )
#
#  concatenate_22 (Concatenate)   (None, 128, 128, 96  0           ['batch_normalization_61[0][0]',
#                                 )                                 'batch_normalization_63[0][0]',
#                                                                   'batch_normalization_56[0][0]']
#
#  activation_39 (Activation)     (None, 128, 128, 96  0           ['concatenate_22[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 16  6160       ['activation_39[0][0]']
#  spose)                         )
#
#  concatenate_23 (Concatenate)   (None, 256, 256, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'activation_4[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 256, 256, 16  9232        ['concatenate_23[0][0]']
#                                 )
#
#  batch_normalization_66 (BatchN  (None, 256, 256, 16  64         ['conv2d_66[0][0]']
#  ormalization)                  )
#
#  activation_40 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_66[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 256, 256, 16  2320        ['activation_40[0][0]']
#                                 )
#
#  batch_normalization_67 (BatchN  (None, 256, 256, 16  64         ['conv2d_67[0][0]']
#  ormalization)                  )
#
#  activation_41 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_67[0][0]']
#                                 )
#
#  conv2d_65 (Conv2D)             (None, 256, 256, 16  9232        ['concatenate_23[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 256, 256, 16  2320        ['activation_41[0][0]']
#                                 )
#
#  batch_normalization_65 (BatchN  (None, 256, 256, 16  64         ['conv2d_65[0][0]']
#  ormalization)                  )
#
#  batch_normalization_68 (BatchN  (None, 256, 256, 16  64         ['conv2d_68[0][0]']
#  ormalization)                  )
#
#  concatenate_24 (Concatenate)   (None, 256, 256, 32  0           ['batch_normalization_65[0][0]',
#                                 )                                 'batch_normalization_68[0][0]']
#
#  activation_42 (Activation)     (None, 256, 256, 32  0           ['concatenate_24[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 256, 256, 16  4624        ['activation_42[0][0]']
#                                 )
#
#  batch_normalization_70 (BatchN  (None, 256, 256, 16  64         ['conv2d_70[0][0]']
#  ormalization)                  )
#
#  activation_43 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_70[0][0]']
#                                 )
#
#  conv2d_69 (Conv2D)             (None, 256, 256, 16  4624        ['activation_42[0][0]']
#                                 )
#
#  conv2d_71 (Conv2D)             (None, 256, 256, 16  2320        ['activation_43[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 256, 256, 16  1040        ['concatenate_23[0][0]']
#                                 )
#
#  batch_normalization_69 (BatchN  (None, 256, 256, 16  64         ['conv2d_69[0][0]']
#  ormalization)                  )
#
#  batch_normalization_71 (BatchN  (None, 256, 256, 16  64         ['conv2d_71[0][0]']
#  ormalization)                  )
#
#  batch_normalization_64 (BatchN  (None, 256, 256, 16  64         ['conv2d_64[0][0]']
#  ormalization)                  )
#
#  concatenate_25 (Concatenate)   (None, 256, 256, 48  0           ['batch_normalization_69[0][0]',
#                                 )                                 'batch_normalization_71[0][0]',
#                                                                   'batch_normalization_64[0][0]']
#
#  activation_44 (Activation)     (None, 256, 256, 48  0           ['concatenate_25[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 256, 256, 1)  49          ['activation_44[0][0]']
#
# ==================================================================================================
# Total params: 14,038,449
# Trainable params: 14,026,673
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=20
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="unet.hdf5",
                               verbose=1,
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )

# %%
history = model.fit(train_gen,
          steps_per_epoch = len(df_train)/BATCH_SIZE,
          epochs = EPOCHS,
          callbacks = [checkpointer, earlystopping, reduce_lr],
          validation_data = test_gen,
          validation_steps= len(df_val)/ BATCH_SIZE)
# Out:
# Found 2838 validated image filenames.
# Found 2838 validated image filenames.
# Epoch 1/35
# 178/177 [==============================] - ETA: -7s - loss: 0.5742 - binary_accuracy: 0.9688 - tversky_index: 0.3820 - dice_coefficient: 0.3696 - sensitivity: 0.4839 - specificity: 0.9739Found 501 validated image filenames.
# Found 501 validated image filenames.
#
# Epoch 1: val_loss improved from inf to 0.40429, saving model to unet.hdf5
# 177/177 [==============================] - 2628s 15s/step - loss: 0.5742 - binary_accuracy: 0.9688 - tversky_index: 0.3820 - dice_coefficient: 0.3696 - sensitivity: 0.4839 - specificity: 0.9739 - val_loss: 0.4043 - val_binary_accuracy: 0.9887 - val_tversky_index: 0.2799 - val_dice_coefficient: 0.2847 - val_sensitivity: 0.2982 - val_specificity: 0.9955 - lr: 0.0500
# Epoch 2/35
# 178/177 [==============================] - ETA: 0s - loss: 0.3111 - binary_accuracy: 0.9898 - tversky_index: 0.4906 - dice_coefficient: 0.4872 - sensitivity: 0.5207 - specificity: 0.9948
# Epoch 2: val_loss improved from 0.40429 to 0.35396, saving model to unet.hdf5
# 177/177 [==============================] - 289s 2s/step - loss: 0.3111 - binary_accuracy: 0.9898 - tversky_index: 0.4906 - dice_coefficient: 0.4872 - sensitivity: 0.5207 - specificity: 0.9948 - val_loss: 0.3540 - val_binary_accuracy: 0.9866 - val_tversky_index: 0.4101 - val_dice_coefficient: 0.3873 - val_sensitivity: 0.4835 - val_specificity: 0.9915 - lr: 0.0500
# Epoch 3/35
# 178/177 [==============================] - ETA: 0s - loss: 0.2774 - binary_accuracy: 0.9909 - tversky_index: 0.5471 - dice_coefficient: 0.5408 - sensitivity: 0.5828 - specificity: 0.9951
# Epoch 3: val_loss improved from 0.35396 to 0.33557, saving model to unet.hdf5
# 177/177 [==============================] - 289s 2s/step - loss: 0.2774 - binary_accuracy: 0.9909 - tversky_index: 0.5471 - dice_coefficient: 0.5408 - sensitivity: 0.5828 - specificity: 0.9951 - val_loss: 0.3356 - val_binary_accuracy: 0.9859 - val_tversky_index: 0.5076 - val_dice_coefficient: 0.4548 - val_sensitivity: 0.6688 - val_specificity: 0.9889 - lr: 0.0500
# Epoch 4/35
# 178/177 [==============================] - ETA: 0s - loss: 0.2361 - binary_accuracy: 0.9923 - tversky_index: 0.6253 - dice_coefficient: 0.6187 - sensitivity: 0.6591 - specificity: 0.9960
# Epoch 4: val_loss did not improve from 0.33557
# 177/177 [==============================] - 287s 2s/step - loss: 0.2361 - binary_accuracy: 0.9923 - tversky_index: 0.6253 - dice_coefficient: 0.6187 - sensitivity: 0.6591 - specificity: 0.9960 - val_loss: 0.4143 - val_binary_accuracy: 0.9785 - val_tversky_index: 0.4957 - val_dice_coefficient: 0.4159 - val_sensitivity: 0.7913 - val_specificity: 0.9807 - lr: 0.0500
# Epoch 5/35
# 178/177 [==============================] - ETA: 0s - loss: 0.2308 - binary_accuracy: 0.9927 - tversky_index: 0.6362 - dice_coefficient: 0.6237 - sensitivity: 0.6874 - specificity: 0.9958
# Epoch 5: val_loss improved from 0.33557 to 0.21233, saving model to unet.hdf5
# 177/177 [==============================] - 289s 2s/step - loss: 0.2308 - binary_accuracy: 0.9927 - tversky_index: 0.6362 - dice_coefficient: 0.6237 - sensitivity: 0.6874 - specificity: 0.9958 - val_loss: 0.2123 - val_binary_accuracy: 0.9942 - val_tversky_index: 0.6656 - val_dice_coefficient: 0.6586 - val_sensitivity: 0.6899 - val_specificity: 0.9970 - lr: 0.0500
# Epoch 6/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1830 - binary_accuracy: 0.9943 - tversky_index: 0.7186 - dice_coefficient: 0.7051 - sensitivity: 0.7584 - specificity: 0.9968
# Epoch 6: val_loss did not improve from 0.21233
# 177/177 [==============================] - 287s 2s/step - loss: 0.1830 - binary_accuracy: 0.9943 - tversky_index: 0.7186 - dice_coefficient: 0.7051 - sensitivity: 0.7584 - specificity: 0.9968 - val_loss: 0.2683 - val_binary_accuracy: 0.9939 - val_tversky_index: 0.5435 - val_dice_coefficient: 0.5961 - val_sensitivity: 0.4849 - val_specificity: 0.9992 - lr: 0.0500
# Epoch 7/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1674 - binary_accuracy: 0.9951 - tversky_index: 0.7457 - dice_coefficient: 0.7384 - sensitivity: 0.7734 - specificity: 0.9975
# Epoch 7: val_loss improved from 0.21233 to 0.18977, saving model to unet.hdf5
# 177/177 [==============================] - 289s 2s/step - loss: 0.1674 - binary_accuracy: 0.9951 - tversky_index: 0.7457 - dice_coefficient: 0.7384 - sensitivity: 0.7734 - specificity: 0.9975 - val_loss: 0.1898 - val_binary_accuracy: 0.9956 - val_tversky_index: 0.7109 - val_dice_coefficient: 0.7204 - val_sensitivity: 0.7078 - val_specificity: 0.9980 - lr: 0.0500
# Epoch 8/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1617 - binary_accuracy: 0.9950 - tversky_index: 0.7524 - dice_coefficient: 0.7401 - sensitivity: 0.7873 - specificity: 0.9973
# Epoch 8: val_loss did not improve from 0.18977
# 177/177 [==============================] - 288s 2s/step - loss: 0.1617 - binary_accuracy: 0.9950 - tversky_index: 0.7524 - dice_coefficient: 0.7401 - sensitivity: 0.7873 - specificity: 0.9973 - val_loss: 0.2146 - val_binary_accuracy: 0.9950 - val_tversky_index: 0.6524 - val_dice_coefficient: 0.6872 - val_sensitivity: 0.6151 - val_specificity: 0.9988 - lr: 0.0500
# Epoch 9/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1607 - binary_accuracy: 0.9953 - tversky_index: 0.7557 - dice_coefficient: 0.7470 - sensitivity: 0.7803 - specificity: 0.9975
# Epoch 9: val_loss did not improve from 0.18977
# 177/177 [==============================] - 288s 2s/step - loss: 0.1607 - binary_accuracy: 0.9953 - tversky_index: 0.7557 - dice_coefficient: 0.7470 - sensitivity: 0.7803 - specificity: 0.9975 - val_loss: 0.2575 - val_binary_accuracy: 0.9947 - val_tversky_index: 0.5438 - val_dice_coefficient: 0.5846 - val_sensitivity: 0.4997 - val_specificity: 0.9992 - lr: 0.0500
# Epoch 10/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1513 - binary_accuracy: 0.9955 - tversky_index: 0.7706 - dice_coefficient: 0.7576 - sensitivity: 0.8052 - specificity: 0.9975
# Epoch 10: val_loss did not improve from 0.18977
# 177/177 [==============================] - 287s 2s/step - loss: 0.1513 - binary_accuracy: 0.9955 - tversky_index: 0.7706 - dice_coefficient: 0.7576 - sensitivity: 0.8052 - specificity: 0.9975 - val_loss: 0.1977 - val_binary_accuracy: 0.9963 - val_tversky_index: 0.6813 - val_dice_coefficient: 0.7075 - val_sensitivity: 0.6459 - val_specificity: 0.9990 - lr: 0.0500
# Epoch 11/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1315 - binary_accuracy: 0.9961 - tversky_index: 0.8045 - dice_coefficient: 0.7919 - sensitivity: 0.8369 - specificity: 0.9978
# Epoch 11: val_loss improved from 0.18977 to 0.15868, saving model to unet.hdf5
# 177/177 [==============================] - 289s 2s/step - loss: 0.1315 - binary_accuracy: 0.9961 - tversky_index: 0.8045 - dice_coefficient: 0.7919 - sensitivity: 0.8369 - specificity: 0.9978 - val_loss: 0.1587 - val_binary_accuracy: 0.9960 - val_tversky_index: 0.7485 - val_dice_coefficient: 0.7591 - val_sensitivity: 0.7408 - val_specificity: 0.9982 - lr: 0.0500
# Epoch 12/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1317 - binary_accuracy: 0.9961 - tversky_index: 0.8039 - dice_coefficient: 0.7908 - sensitivity: 0.8358 - specificity: 0.9978
# Epoch 12: val_loss improved from 0.15868 to 0.13922, saving model to unet.hdf5
# 177/177 [==============================] - 289s 2s/step - loss: 0.1317 - binary_accuracy: 0.9961 - tversky_index: 0.8039 - dice_coefficient: 0.7908 - sensitivity: 0.8358 - specificity: 0.9978 - val_loss: 0.1392 - val_binary_accuracy: 0.9964 - val_tversky_index: 0.7856 - val_dice_coefficient: 0.7818 - val_sensitivity: 0.7978 - val_specificity: 0.9981 - lr: 0.0500
# Epoch 13/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1127 - binary_accuracy: 0.9966 - tversky_index: 0.8334 - dice_coefficient: 0.8192 - sensitivity: 0.8655 - specificity: 0.9979
# Epoch 13: val_loss did not improve from 0.13922
# 177/177 [==============================] - 287s 2s/step - loss: 0.1127 - binary_accuracy: 0.9966 - tversky_index: 0.8334 - dice_coefficient: 0.8192 - sensitivity: 0.8655 - specificity: 0.9979 - val_loss: 0.1488 - val_binary_accuracy: 0.9966 - val_tversky_index: 0.7764 - val_dice_coefficient: 0.7794 - val_sensitivity: 0.7777 - val_specificity: 0.9984 - lr: 0.0500
# Epoch 14/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1122 - binary_accuracy: 0.9966 - tversky_index: 0.8365 - dice_coefficient: 0.8206 - sensitivity: 0.8714 - specificity: 0.9979
# Epoch 14: val_loss improved from 0.13922 to 0.11993, saving model to unet.hdf5
# 177/177 [==============================] - 288s 2s/step - loss: 0.1122 - binary_accuracy: 0.9966 - tversky_index: 0.8365 - dice_coefficient: 0.8206 - sensitivity: 0.8714 - specificity: 0.9979 - val_loss: 0.1199 - val_binary_accuracy: 0.9967 - val_tversky_index: 0.8220 - val_dice_coefficient: 0.8324 - val_sensitivity: 0.8126 - val_specificity: 0.9988 - lr: 0.0500
# Epoch 15/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1088 - binary_accuracy: 0.9968 - tversky_index: 0.8404 - dice_coefficient: 0.8279 - sensitivity: 0.8674 - specificity: 0.9981
# Epoch 15: val_loss did not improve from 0.11993
# 177/177 [==============================] - 288s 2s/step - loss: 0.1088 - binary_accuracy: 0.9968 - tversky_index: 0.8404 - dice_coefficient: 0.8279 - sensitivity: 0.8674 - specificity: 0.9981 - val_loss: 0.1514 - val_binary_accuracy: 0.9965 - val_tversky_index: 0.7622 - val_dice_coefficient: 0.7677 - val_sensitivity: 0.7616 - val_specificity: 0.9983 - lr: 0.0500
# Epoch 16/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1067 - binary_accuracy: 0.9969 - tversky_index: 0.8421 - dice_coefficient: 0.8279 - sensitivity: 0.8710 - specificity: 0.9981
# Epoch 16: val_loss did not improve from 0.11993
# 177/177 [==============================] - 288s 2s/step - loss: 0.1067 - binary_accuracy: 0.9969 - tversky_index: 0.8421 - dice_coefficient: 0.8279 - sensitivity: 0.8710 - specificity: 0.9981 - val_loss: 0.1352 - val_binary_accuracy: 0.9972 - val_tversky_index: 0.7934 - val_dice_coefficient: 0.8053 - val_sensitivity: 0.7814 - val_specificity: 0.9990 - lr: 0.0500
# Epoch 17/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1057 - binary_accuracy: 0.9969 - tversky_index: 0.8458 - dice_coefficient: 0.8342 - sensitivity: 0.8709 - specificity: 0.9982
# Epoch 17: val_loss did not improve from 0.11993
# 177/177 [==============================] - 288s 2s/step - loss: 0.1057 - binary_accuracy: 0.9969 - tversky_index: 0.8458 - dice_coefficient: 0.8342 - sensitivity: 0.8709 - specificity: 0.9982 - val_loss: 0.1201 - val_binary_accuracy: 0.9969 - val_tversky_index: 0.8180 - val_dice_coefficient: 0.8215 - val_sensitivity: 0.8186 - val_specificity: 0.9986 - lr: 0.0500
# Epoch 18/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1045 - binary_accuracy: 0.9970 - tversky_index: 0.8465 - dice_coefficient: 0.8335 - sensitivity: 0.8736 - specificity: 0.9982
# Epoch 18: val_loss improved from 0.11993 to 0.11089, saving model to unet.hdf5
# 177/177 [==============================] - 289s 2s/step - loss: 0.1045 - binary_accuracy: 0.9970 - tversky_index: 0.8465 - dice_coefficient: 0.8335 - sensitivity: 0.8736 - specificity: 0.9982 - val_loss: 0.1109 - val_binary_accuracy: 0.9971 - val_tversky_index: 0.8403 - val_dice_coefficient: 0.8291 - val_sensitivity: 0.8631 - val_specificity: 0.9983 - lr: 0.0500
# Epoch 19/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0958 - binary_accuracy: 0.9972 - tversky_index: 0.8587 - dice_coefficient: 0.8462 - sensitivity: 0.8831 - specificity: 0.9983
# Epoch 19: val_loss did not improve from 0.11089
# 177/177 [==============================] - 287s 2s/step - loss: 0.0958 - binary_accuracy: 0.9972 - tversky_index: 0.8587 - dice_coefficient: 0.8462 - sensitivity: 0.8831 - specificity: 0.9983 - val_loss: 0.1344 - val_binary_accuracy: 0.9965 - val_tversky_index: 0.7911 - val_dice_coefficient: 0.7749 - val_sensitivity: 0.8272 - val_specificity: 0.9978 - lr: 0.0500
# Epoch 20/35
# 178/177 [==============================] - ETA: 0s - loss: 0.1025 - binary_accuracy: 0.9971 - tversky_index: 0.8460 - dice_coefficient: 0.8338 - sensitivity: 0.8711 - specificity: 0.9982
# Epoch 20: val_loss did not improve from 0.11089
# 177/177 [==============================] - 288s 2s/step - loss: 0.1025 - binary_accuracy: 0.9971 - tversky_index: 0.8460 - dice_coefficient: 0.8338 - sensitivity: 0.8711 - specificity: 0.9982 - val_loss: 0.1164 - val_binary_accuracy: 0.9970 - val_tversky_index: 0.8291 - val_dice_coefficient: 0.8332 - val_sensitivity: 0.8284 - val_specificity: 0.9986 - lr: 0.0500
# Epoch 21/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0980 - binary_accuracy: 0.9973 - tversky_index: 0.8541 - dice_coefficient: 0.8421 - sensitivity: 0.8786 - specificity: 0.9983
# Epoch 21: val_loss did not improve from 0.11089
# 177/177 [==============================] - 288s 2s/step - loss: 0.0980 - binary_accuracy: 0.9973 - tversky_index: 0.8541 - dice_coefficient: 0.8421 - sensitivity: 0.8786 - specificity: 0.9983 - val_loss: 0.1242 - val_binary_accuracy: 0.9970 - val_tversky_index: 0.8175 - val_dice_coefficient: 0.8154 - val_sensitivity: 0.8289 - val_specificity: 0.9984 - lr: 0.0500
# Epoch 22/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0877 - binary_accuracy: 0.9974 - tversky_index: 0.8741 - dice_coefficient: 0.8626 - sensitivity: 0.8981 - specificity: 0.9984
# Epoch 22: val_loss improved from 0.11089 to 0.09539, saving model to unet.hdf5
# 177/177 [==============================] - 289s 2s/step - loss: 0.0877 - binary_accuracy: 0.9974 - tversky_index: 0.8741 - dice_coefficient: 0.8626 - sensitivity: 0.8981 - specificity: 0.9984 - val_loss: 0.0954 - val_binary_accuracy: 0.9975 - val_tversky_index: 0.8591 - val_dice_coefficient: 0.8625 - val_sensitivity: 0.8577 - val_specificity: 0.9988 - lr: 0.0500
# Epoch 23/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0931 - binary_accuracy: 0.9972 - tversky_index: 0.8664 - dice_coefficient: 0.8516 - sensitivity: 0.8941 - specificity: 0.9982
# Epoch 23: val_loss did not improve from 0.09539
# 177/177 [==============================] - 287s 2s/step - loss: 0.0931 - binary_accuracy: 0.9972 - tversky_index: 0.8664 - dice_coefficient: 0.8516 - sensitivity: 0.8941 - specificity: 0.9982 - val_loss: 0.1170 - val_binary_accuracy: 0.9972 - val_tversky_index: 0.8135 - val_dice_coefficient: 0.8130 - val_sensitivity: 0.8238 - val_specificity: 0.9986 - lr: 0.0500
# Epoch 24/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0911 - binary_accuracy: 0.9972 - tversky_index: 0.8685 - dice_coefficient: 0.8532 - sensitivity: 0.8979 - specificity: 0.9982
# Epoch 24: val_loss did not improve from 0.09539
# 177/177 [==============================] - 287s 2s/step - loss: 0.0911 - binary_accuracy: 0.9972 - tversky_index: 0.8685 - dice_coefficient: 0.8532 - sensitivity: 0.8979 - specificity: 0.9982 - val_loss: 0.1546 - val_binary_accuracy: 0.9964 - val_tversky_index: 0.7614 - val_dice_coefficient: 0.7558 - val_sensitivity: 0.7752 - val_specificity: 0.9979 - lr: 0.0500
# Epoch 25/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0991 - binary_accuracy: 0.9970 - tversky_index: 0.8558 - dice_coefficient: 0.8401 - sensitivity: 0.8870 - specificity: 0.9981
# Epoch 25: val_loss did not improve from 0.09539
# 177/177 [==============================] - 288s 2s/step - loss: 0.0991 - binary_accuracy: 0.9970 - tversky_index: 0.8558 - dice_coefficient: 0.8401 - sensitivity: 0.8870 - specificity: 0.9981 - val_loss: 0.1332 - val_binary_accuracy: 0.9970 - val_tversky_index: 0.7967 - val_dice_coefficient: 0.8185 - val_sensitivity: 0.7719 - val_specificity: 0.9992 - lr: 0.0500
# Epoch 26/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0875 - binary_accuracy: 0.9973 - tversky_index: 0.8749 - dice_coefficient: 0.8624 - sensitivity: 0.8990 - specificity: 0.9984
# Epoch 26: val_loss improved from 0.09539 to 0.09202, saving model to unet.hdf5
# 177/177 [==============================] - 289s 2s/step - loss: 0.0875 - binary_accuracy: 0.9973 - tversky_index: 0.8749 - dice_coefficient: 0.8624 - sensitivity: 0.8990 - specificity: 0.9984 - val_loss: 0.0920 - val_binary_accuracy: 0.9978 - val_tversky_index: 0.8697 - val_dice_coefficient: 0.8680 - val_sensitivity: 0.8754 - val_specificity: 0.9989 - lr: 0.0500
# Epoch 27/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0778 - binary_accuracy: 0.9976 - tversky_index: 0.8900 - dice_coefficient: 0.8718 - sensitivity: 0.9234 - specificity: 0.9983
# Epoch 27: val_loss improved from 0.09202 to 0.07789, saving model to unet.hdf5
# 177/177 [==============================] - 290s 2s/step - loss: 0.0778 - binary_accuracy: 0.9976 - tversky_index: 0.8900 - dice_coefficient: 0.8718 - sensitivity: 0.9234 - specificity: 0.9983 - val_loss: 0.0779 - val_binary_accuracy: 0.9979 - val_tversky_index: 0.8853 - val_dice_coefficient: 0.8872 - val_sensitivity: 0.8856 - val_specificity: 0.9990 - lr: 0.0500
# Epoch 28/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0781 - binary_accuracy: 0.9976 - tversky_index: 0.8880 - dice_coefficient: 0.8696 - sensitivity: 0.9187 - specificity: 0.9983
# Epoch 28: val_loss improved from 0.07789 to 0.07353, saving model to unet.hdf5
# 177/177 [==============================] - 288s 2s/step - loss: 0.0781 - binary_accuracy: 0.9976 - tversky_index: 0.8880 - dice_coefficient: 0.8696 - sensitivity: 0.9187 - specificity: 0.9983 - val_loss: 0.0735 - val_binary_accuracy: 0.9974 - val_tversky_index: 0.8975 - val_dice_coefficient: 0.8732 - val_sensitivity: 0.9399 - val_specificity: 0.9978 - lr: 0.0500
# Epoch 29/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0724 - binary_accuracy: 0.9977 - tversky_index: 0.8974 - dice_coefficient: 0.8806 - sensitivity: 0.9270 - specificity: 0.9984
# Epoch 29: val_loss improved from 0.07353 to 0.06695, saving model to unet.hdf5
# 177/177 [==============================] - 289s 2s/step - loss: 0.0724 - binary_accuracy: 0.9977 - tversky_index: 0.8974 - dice_coefficient: 0.8806 - sensitivity: 0.9270 - specificity: 0.9984 - val_loss: 0.0670 - val_binary_accuracy: 0.9980 - val_tversky_index: 0.9077 - val_dice_coefficient: 0.8907 - val_sensitivity: 0.9369 - val_specificity: 0.9985 - lr: 0.0500
# Epoch 30/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0691 - binary_accuracy: 0.9978 - tversky_index: 0.9028 - dice_coefficient: 0.8847 - sensitivity: 0.9345 - specificity: 0.9984
# Epoch 30: val_loss improved from 0.06695 to 0.06324, saving model to unet.hdf5
# 177/177 [==============================] - 287s 2s/step - loss: 0.0691 - binary_accuracy: 0.9978 - tversky_index: 0.9028 - dice_coefficient: 0.8847 - sensitivity: 0.9345 - specificity: 0.9984 - val_loss: 0.0632 - val_binary_accuracy: 0.9980 - val_tversky_index: 0.9078 - val_dice_coefficient: 0.8797 - val_sensitivity: 0.9185 - val_specificity: 0.9984 - lr: 0.0500
# Epoch 31/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0705 - binary_accuracy: 0.9978 - tversky_index: 0.8991 - dice_coefficient: 0.8810 - sensitivity: 0.9315 - specificity: 0.9984
# Epoch 31: val_loss did not improve from 0.06324
# 177/177 [==============================] - 283s 2s/step - loss: 0.0705 - binary_accuracy: 0.9978 - tversky_index: 0.8991 - dice_coefficient: 0.8810 - sensitivity: 0.9315 - specificity: 0.9984 - val_loss: 0.0718 - val_binary_accuracy: 0.9982 - val_tversky_index: 0.9002 - val_dice_coefficient: 0.8982 - val_sensitivity: 0.9058 - val_specificity: 0.9991 - lr: 0.0500
# Epoch 32/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0668 - binary_accuracy: 0.9978 - tversky_index: 0.9056 - dice_coefficient: 0.8882 - sensitivity: 0.9360 - specificity: 0.9985
# Epoch 32: val_loss did not improve from 0.06324
# 177/177 [==============================] - 283s 2s/step - loss: 0.0668 - binary_accuracy: 0.9978 - tversky_index: 0.9056 - dice_coefficient: 0.8882 - sensitivity: 0.9360 - specificity: 0.9985 - val_loss: 0.0681 - val_binary_accuracy: 0.9981 - val_tversky_index: 0.9036 - val_dice_coefficient: 0.8933 - val_sensitivity: 0.9234 - val_specificity: 0.9987 - lr: 0.0500
# Epoch 33/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0697 - binary_accuracy: 0.9979 - tversky_index: 0.8961 - dice_coefficient: 0.8786 - sensitivity: 0.9269 - specificity: 0.9985
# Epoch 33: val_loss did not improve from 0.06324
# 177/177 [==============================] - 284s 2s/step - loss: 0.0697 - binary_accuracy: 0.9979 - tversky_index: 0.8961 - dice_coefficient: 0.8786 - sensitivity: 0.9269 - specificity: 0.9985 - val_loss: 0.0649 - val_binary_accuracy: 0.9981 - val_tversky_index: 0.9110 - val_dice_coefficient: 0.8985 - val_sensitivity: 0.9338 - val_specificity: 0.9987 - lr: 0.0500
# Epoch 34/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0638 - binary_accuracy: 0.9979 - tversky_index: 0.9096 - dice_coefficient: 0.8928 - sensitivity: 0.9375 - specificity: 0.9985
# Epoch 34: val_loss did not improve from 0.06324
# 177/177 [==============================] - 284s 2s/step - loss: 0.0638 - binary_accuracy: 0.9979 - tversky_index: 0.9096 - dice_coefficient: 0.8928 - sensitivity: 0.9375 - specificity: 0.9985 - val_loss: 0.0691 - val_binary_accuracy: 0.9980 - val_tversky_index: 0.9048 - val_dice_coefficient: 0.8938 - val_sensitivity: 0.9247 - val_specificity: 0.9987 - lr: 0.0500
# Epoch 35/35
# 178/177 [==============================] - ETA: 0s - loss: 0.0633 - binary_accuracy: 0.9979 - tversky_index: 0.9116 - dice_coefficient: 0.8942 - sensitivity: 0.9413 - specificity: 0.9985
# Epoch 35: val_loss did not improve from 0.06324
# 177/177 [==============================] - 285s 2s/step - loss: 0.0633 - binary_accuracy: 0.9979 - tversky_index: 0.9116 - dice_coefficient: 0.8942 - sensitivity: 0.9413 - specificity: 0.9985 - val_loss: 0.0763 - val_binary_accuracy: 0.9982 - val_tversky_index: 0.8833 - val_dice_coefficient: 0.8706 - val_sensitivity: 0.9020 - val_specificity: 0.9987 - lr: 0.0500

# %%
model.save_weights("/content/drive/MyDrive/unet.h5")

# %%
model_json = model.to_json()
with open("unet.json", "w") as json_file:
    json_file.write(model_json)

# %%
test_gen = train_generator(df_test, BATCH_SIZE,
                                dict(),
                                target_size=IMG_SIZE)
results = model.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)
print("Test loss: ",results[0])
print("Test accuracy: ",results[1])
print("Test tversky: ",results[2])
print("Test Dice Coefficent: ",results[3])
print("Test sensitivity: ",results[4])
print("Test specificity: ",results[5])
# Out:
# Found 590 validated image filenames.
# Found 590 validated image filenames.
# 36/36 [==============================] - 571s 16s/step - loss: 0.0714 - binary_accuracy: 0.9979 - tversky_index: 0.9006 - dice_coefficient: 0.8910 - sensitivity: 0.9180 - specificity: 0.9987
# Test loss:  0.0713624507188797
# Test accuracy:  0.9978870749473572
# Test tversky:  0.9005983471870422
# Test Dice Coefficent:  0.8909568786621094
# Test sensitivity:  0.9179515242576599
# Test specificity:  0.9987136125564575

# %%
for index in range(len(df_test)):
    img = cv.imread(df_test['image_path'].iloc[index])
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    img = cv.resize(img ,IMG_SIZE)
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)
    img = np.squeeze(img)

    original = img.copy()
    fig, ax = plt.subplots(1,3,figsize = (15,5))
    ax[0].imshow(original)
    ax[0].set_xlabel('Original Image')

    main = original.copy()
    label = cv.imread(df_test['mask_path'].iloc[index])
    sample = np.array(np.squeeze(label), dtype = np.uint8)
    sample = cv.resize(sample ,IMG_SIZE)
    contours, hier = cv2.findContours(sample[:,:,0],cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)
    sample_over_gt = cv2.drawContours(main, contours, -1,[0,255,0], thickness=-1)
    ax[1].imshow(sample_over_gt)
    ax[1].set_xlabel('Ground Truth')

    main = original.copy()
    sample = np.array(np.squeeze(pred) > 0.5, dtype = np.uint8)
    contours, hier = cv2.findContours(sample,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)
    sample_over_pr = cv2.drawContours(main, contours, -1, [0,255,0], thickness=-1)
    ax[2].imshow(sample_over_pr)
    ax[2].set_xlabel("Hybrid Prediction")

plt.show()

# %%
def plot_segm_history(history, metrics, losses, name):
    """[summary]

    Args:
        history ([type]): [description]
        metrics (list, optional): [description]. Defaults to ["iou", "val_iou"].
        losses (list, optional): [description]. Defaults to ["loss", "val_loss"].
    """
    # summarize history for iou
    plt.figure(figsize=(12, 6))
    for metric in metrics:
        plt.plot(history.history[metric], linewidth=3)
    plt.suptitle(f"{name} vs epochs", fontsize=20)
    plt.ylabel(f"{name}", fontsize=20)
    plt.xlabel("epoch", fontsize=20)
    # plt.yticks(np.arange(0.3, 1, step=0.02), fontsize=35)
    # plt.xticks(fontsize=35)
    plt.legend(metrics, loc="center right", fontsize=15)
    plt.savefig(f"{name}.png")
    plt.show()
    # summarize history for loss
    plt.figure(figsize=(12, 6))
    for loss in losses:
        plt.plot(history.history[loss], linewidth=3)
    plt.suptitle("loss over epochs", fontsize=20)
    plt.ylabel("loss", fontsize=20)
    plt.xlabel("epoch", fontsize=20)
    # plt.yticks(np.arange(0, 0.2, step=0.005), fontsize=35)
    # plt.xticks(fontsize=35)
    plt.legend(losses, loc="center right", fontsize=15)
    plt.savefig("unet_loss.png")
    plt.show()

# %%
plot_segm_history(
    history, # required - keras training history object
    ['dice_coefficient', 'val_dice_coefficient'], # optional - metrics names to plot
    ['loss', 'val_loss'], 'Dice_coefficient') # optional - loss names to plot

# %%
plot_segm_history(
    history, # required - keras training history object
    ['sensitivity', 'val_sensitivity'], # optional - metrics names to plot
    ['loss', 'val_loss'], 'sensitivity') # optional - loss names to plot

# %%
plot_segm_history(
    history, # required - keras training history object
    ['specificity', 'val_specificity'], # optional - metrics names to plot
    ['loss', 'val_loss'], 'specificity') # optional - loss names to plot

# %%
plot_segm_history(
    history, # required - keras training history object
    ['binary_accuracy', 'val_binary_accuracy'], # optional - metrics names to plot
    ['loss', 'val_loss'], 'accuracy') # optional - loss names to plot

# %%
plot_segm_history(
    history, # required - keras training history object
    ['tversky_index', 'val_tversky_index'], # optional - metrics names to plot
    ['loss', 'val_loss'], 'loss') # optional - loss names to plot
